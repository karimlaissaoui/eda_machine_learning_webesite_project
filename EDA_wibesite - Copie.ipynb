# %% [markdown]
# ## Business Context

# %% [markdown]
# Business Context for Lead Scoring in X Educator
#
# **Business Overview**
#
# X Educator is an online education platform that provides a wide range of courses, certifications, and professional training programs. The platform generates leads through various marketing channels, including:
#
# Social media ads
#
# Webinars
#
# Free trials
#
# Partnerships with organizations
#
# Despite a high volume of leads, the platform faces low conversion rates, making it difficult for the sales team to identify and focus on high-potential prospects.
#
# **Business Challenge**
#
# Low conversion rate: A large number of leads do not convert into paying customers.
#
# Inefficient sales process: The sales team spends time on leads with low intent, reducing efficiency.
#
# Lack of prioritization: There is no clear way to distinguish between high-quality and low-quality leads.
#
# **Business Goal**
#
# To optimize the sales process and increase conversion rates, X Educator wants to implement a Lead Scoring System. This system will:
#
# Prioritize leads based on their likelihood to enroll in a course or purchase a subscription.
# Help the sales team focus on the most promising leads.
# Improve marketing strategies by identifying the characteristics of high-converting leads.

# %% [markdown]
# 1. Identification et Suivi des Leads
#
# Prospect ID : Identifiant unique du lead.
#
# Lead Number : Numéro de suivi attribué au lead.
#
# 📌 Utilité : Permet d’identifier chaque lead de manière unique.
#
# 2. Source et Origine des Leads
#
# Lead Origin : D’où provient le lead (ex : site web, référence, réseaux sociaux, etc.).
#
# Lead Source : La source spécifique (ex : Google Ads, Facebook Ads, Webinaire, etc.).
#
# 📌 Utilité : Aide à analyser quelles sources génèrent les leads les plus qualifiés.
#
# 3. Engagement et Comportement sur le Site
#
# Total Visits : Nombre total de visites du lead sur le site.
#
# Total Time Spent on Website : Temps total passé sur le site par le lead.
#
# Page Views Per Visit : Nombre moyen de pages consultées par visite.
#
# Last Activity : Dernière action effectuée par le lead (ex : email ouvert, formulaire soumis, etc.).
#
# Last Notable Activity : Dernière action notable du lead, souvent une version plus récente de "Last Activity".
#
# 📌 Utilité : Un engagement élevé (plus de visites, plus de temps passé) peut indiquer une forte intention d’achat.
#
# 4. Informations Démographiques et Professionnelles
#
# Country : Pays d’origine du lead.
#
# City : Ville du lead (si disponible).
#
# Specialization : Domaine d’intérêt du lead (ex : Data Science, Finance, Marketing, etc.).
#
# What is your current occupation : Profession actuelle du lead (étudiant, employé, etc.).
#
# What matters most to you in choosing a course : Facteur le plus important pour le lead dans son choix de formation (ex : prix, qualité, reconnaissance du diplôme).
#
# 📌 Utilité : Permet de segmenter les leads en fonction de leur profil et d’adapter la communication.
#
# 5. Intérêt et Sensibilité au Marketing
#
# Do Not Email : Indique si le lead a refusé de recevoir des emails marketing.
#
# Do Not Call : Indique si le lead a refusé les appels téléphoniques.
#
# Receive More Updates About Our Courses : Indique si le lead veut recevoir des mises à jour sur les formations.
#
# Update me on Supply Chain Content : Indique un intérêt spécifique pour le contenu Supply Chain.
#
# Get updates on DM Content : Indique un intérêt spécifique pour le contenu Digital Marketing.
#
# 📌 Utilité : Permet d’optimiser la stratégie de communication en respectant les préférences des leads.
#
# 6. Canaux Publicitaires et Références
#
# Search : Le lead a-t-il recherché activement la plateforme sur Google/Bing ? (Oui/Non)
#
# Magazine : A-t-il été acquis via un magazine ? (Oui/Non)
#
# Newspaper Article : A-t-il découvert la plateforme via un article de journal ?
#
# X Education Forums : A-t-il découvert la plateforme via des forums en ligne ?
#
# Newspaper : A-t-il vu une publicité dans un journal ?
#
# Digital Advertisement : A-t-il vu une publicité en ligne ?
#
# Through Recommendations : A-t-il été recommandé par quelqu'un ?
#
# 📌 Utilité : Identifier les canaux marketing les plus efficaces pour générer des leads qualifiés.
#
# 7. Qualité et Scoring des Leads
#
# Tags : Informations catégoriques sur le lead (ex : "Intéressé", "Ne répond pas", etc.).
#
# Lead Quality : Évaluation de la qualité du lead par l’équipe commerciale (ex : élevé, moyen, faible).
#
# Lead Profile : Catégorie du lead selon son engagement et son historique.
#
# 📌Utilité : Permet d’évaluer la maturité des leads et de les prioriser.
#
# 8. Scores d’Activité et de Profil
#
# Asymmetrique Activity Index : Indice d’activité du lead sur la plateforme.
#
# Asymmetrique Profile Index : Indice de pertinence du profil du lead.
#
# Asymmetrique Activity Score : Score numérique basé sur l’activité du lead.
#
# Asymmetrique Profile Score : Score numérique basé sur la correspondance du lead avec le profil idéal.
#
# 📌 Utilité : Peut être intégré dans un modèle de Lead Scoring pour prioriser les leads les plus engagés.
#
# 9. Engagement avec du Contenu Promotionnel
#
# I agree to pay the amount through cheque : Indique si le lead est prêt à payer par chèque.
#
# A free copy of Mastering The Interview : Indique si le lead a demandé un ebook gratuit (signe d’engagement).
#
# 📌 Utilité : Un lead ayant demandé des ressources gratuites pourrait être plus engagé.
#
# 10. Cible (Variable Dépendante)
#
# Converted : Indique si le lead s'est inscrit à un cours ou a souscrit à un abonnement (1 = Converti, 0 = Non Converti).
#
# 📌 Utilité : Cette variable est la cible principale pour l’analyse et le modèle de Lead Scoring.
#
# 11. Variable Superflue / Erreurs
# Unnamed: 0.1 : Probablement une colonne d’index inutile à supprimer.

# %% [markdown]
# ## import package

# %%
import pandas as pd 
import pathlib
import os
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
import time

# %% [markdown]
# ## import data

# %%
data_train= pd.read_csv("C:/Users/Client/Desktop/R studio project/website_project/training_set.csv")
data_test= pd.read_csv("C:/Users/Client/Desktop/R studio project/website_project/testing_set.csv")
df_test=pd.DataFrame(data_test)
df_train=pd.DataFrame(data_train)
df_train.head()
df_test.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                           Prospect ID  \
# 0             0        5055  e99fa52d-c865-4750-99da-aad6b050cd82
# 1             1         529  a1e2f86e-b265-47ca-a82b-acd45d61066f
# 2             2        3044  03509345-8a4d-4432-b5a5-49a17f9fdda2
# 3             3        8036  73529a68-3f77-4652-ab9b-d14029e2e972
# 4             4        7485  8a610c44-7e8c-43f9-b144-01f12d87ae52
#
#    Lead Number              Lead Origin     Lead Source Do Not Email  \
# 0       611296                      API      Olark Chat           No
# 1       654918  Landing Page Submission  Direct Traffic           No
# 2       630728  Landing Page Submission  Direct Traffic           No
# 3       588182                      API      Olark Chat           No
# 4       592218  Landing Page Submission  Direct Traffic           No
#
#   Do Not Call  TotalVisits  Total Time Spent on Website  ...  \
# 0          No          0.0                            0  ...
# 1          No          2.0                         1012  ...
# 2          No          4.0                          906  ...
# 3          No          0.0                            0  ...
# 4          No          2.0                          127  ...
#
#    Get updates on DM Content Lead Profile          City  \
# 0                         No       Select        Mumbai
# 1                         No       Select        Mumbai
# 2                         No       Select  Other Cities
# 3                         No       Select        Mumbai
# 4                         No       Select  Other Cities
#
#   Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0                   02.Medium                  02.Medium
# 1                   02.Medium                    01.High
# 2                   02.Medium                  02.Medium
# 3                     01.High                  02.Medium
# 4                     01.High                  02.Medium
#
#   Asymmetrique Activity Score Asymmetrique Profile Score  \
# 0                   14.276482                  16.247169
# 1                   13.000000                  18.000000
# 2                   14.276482                  16.247169
# 3                   17.000000                  15.000000
# 4                   16.000000                  16.000000
#
#   I agree to pay the amount through cheque  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              SMS Sent
# 1                                    Yes              Modified
# 2                                    Yes              SMS Sent
# 3                                     No              Modified
# 4                                     No          Email Opened
#
# [5 rows x 38 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 38 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Unnamed: 0                                     6468 non-null   int64
#  1   Prospect ID                                    6468 non-null   object
#  2   Lead Number                                    6468 non-null   float64
#  3   Lead Origin                                    6468 non-null   object
#  4   Lead Source                                    6437 non-null   object
#  5   Do Not Email                                   6468 non-null   object
#  6   Do Not Call                                    6468 non-null   object
#  7   TotalVisits                                    6371 non-null   float64
#  8   Total Time Spent on Website                    6468 non-null   float64
#  9   Page Views Per Visit                           6371 non-null   float64
#  10  Last Activity                                  6396 non-null   object
#  11  Country                                        4762 non-null   object
#  12  Specialization                                 5479 non-null   object
#  13  How did you hear about X Education             4937 non-null   object
#  14  What is your current occupation                4621 non-null   object
#  15  What matters most to you in choosing a course  4605 non-null   object
#  16  Search                                         6468 non-null   object
#  17  Magazine                                       6468 non-null   object
#  18  Newspaper Article                              6468 non-null   object
#  19  X Education Forums                             6468 non-null   object
#  20  Newspaper                                      6468 non-null   object
#  21  Digital Advertisement                          6468 non-null   object
#  22  Through Recommendations                        6468 non-null   object
#  23  Receive More Updates About Our Courses         6468 non-null   object
#  24  Tags                                           4140 non-null   object
#  25  Lead Quality                                   3173 non-null   object
#  26  Update me on Supply Chain Content              6468 non-null   object
#  27  Get updates on DM Content                      6468 non-null   object
#  28  Lead Profile                                   4605 non-null   object
#  29  City                                           5494 non-null   object
#  30  Asymmetrique Activity Index                    3521 non-null   object
#  31  Asymmetrique Profile Index                     3521 non-null   object
#  32  Asymmetrique Activity Score                    3521 non-null   float64
#  33  Asymmetrique Profile Score                     3521 non-null   float64
#  34  I agree to pay the amount through cheque       6468 non-null   object
#  35  A free copy of Mastering The Interview         6468 non-null   object
#  36  Last Notable Activity                          6468 non-null   object
#  37  Converted                                      6468 non-null   float64
# dtypes: float64(7), int64(1), object(30)
# memory usage: 1.9+ MB

# %%
df_train.describe()
# Out:
#         Unnamed: 0    Lead Number  TotalVisits  Total Time Spent on Website  \
# count  6468.000000    6468.000000  6371.000000                  6468.000000
# mean   4602.342919  617330.860390     3.449694                   491.114255
# std    2664.626796   23395.991366     4.013490                   550.012599
# min       0.000000  579533.000000     0.000000                     0.000000
# 25%    2284.750000  596657.750000     1.000000                    14.000000
# 50%    4616.500000  615495.000000     3.000000                   252.000000
# 75%    6899.250000  637641.750000     5.000000                   946.250000
# max    9239.000000  660737.000000   115.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           6371.000000                  3521.000000
# mean               2.374720                    14.318943
# std                2.183707                     1.380549
# min                0.000000                     7.000000
# 25%                1.000000                    14.000000
# 50%                2.000000                    14.000000
# 75%                3.000000                    15.000000
# max               55.000000                    18.000000
#
#        Asymmetrique Profile Score    Converted
# count                 3521.000000  6468.000000
# mean                    16.386538     0.387755
# std                      1.815567     0.487276
# min                     11.000000     0.000000
# 25%                     15.000000     0.000000
# 50%                     16.000000     0.000000
# 75%                     18.000000     1.000000
# max                     20.000000     1.000000

# %%
df_test.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0    Lead Number  TotalVisits  \
# count   2772.000000  2772.000000    2772.000000  2772.000000
# mean    1385.500000  4659.533189  616856.111111     3.434846
# std      800.351798  2674.253977   23430.178333     6.355333
# min        0.000000     1.000000  579546.000000     0.000000
# 25%      692.750000  2379.750000  596048.250000     1.000000
# 50%     1385.500000  4634.000000  615301.500000     3.000000
# 75%     2078.250000  6980.250000  636855.250000     5.000000
# max     2771.000000  9236.000000  660728.000000   251.000000
#
#        Total Time Spent on Website  Page Views Per Visit  \
# count                  2772.000000           2772.000000
# mean                    479.727633              2.335070
# std                     543.362334              2.093383
# min                       0.000000              0.000000
# 25%                       5.750000              1.000000
# 50%                     241.500000              2.000000
# 75%                     899.250000              3.000000
# max                    2207.000000             24.000000
#
#        Asymmetrique Activity Score  Asymmetrique Profile Score
# count                  2772.000000                 2772.000000
# mean                     14.276482                   16.247169
# std                       1.030789                    1.323155
# min                       9.000000                   11.000000
# 25%                      14.000000                   16.000000
# 50%                      14.276482                   16.247169
# 75%                      14.276482                   16.247169
# max                      17.000000                   20.000000

# %% [markdown]
# ## merge data

# %%
data_new = pd.concat([data_train, data_test], axis=0)

data_new.reset_index(drop=True, inplace=True)
data_new.to_csv("webesite_data.csv", index=False)
print(data_new.shape)
# Out:
# (9240, 39)

# %%
data_new.describe()
# Out:
#         Unnamed: 0    Lead Number  TotalVisits  Total Time Spent on Website  \
# count  9240.000000    9240.000000  9143.000000                  9240.000000
# mean   4619.500000  617188.435606     3.445192                   487.698268
# std    2667.502577   23405.995698     4.844220                   548.021466
# min       0.000000  579533.000000     0.000000                     0.000000
# 25%    2309.750000  596484.500000     1.000000                    12.000000
# 50%    4619.500000  615479.000000     3.000000                   248.000000
# 75%    6929.250000  637387.250000     5.000000                   936.000000
# max    9239.000000  660737.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9143.000000                  6293.000000
# mean               2.362699                    14.300240
# std                2.156685                     1.238801
# min                0.000000                     7.000000
# 25%                1.000000                    14.000000
# 50%                2.000000                    14.276482
# 75%                3.000000                    15.000000
# max               55.000000                    18.000000
#
#        Asymmetrique Profile Score    Converted  Unnamed: 0.1
# count                 6293.000000  6468.000000   2772.000000
# mean                    16.325147     0.387755   1385.500000
# std                      1.618607     0.487276    800.351798
# min                     11.000000     0.000000      0.000000
# 25%                     15.000000     0.000000    692.750000
# 50%                     16.247169     0.000000   1385.500000
# 75%                     18.000000     1.000000   2078.250000
# max                     20.000000     1.000000   2771.000000

# %%
df=data_new
df.columns
# Out:
# Index(['Unnamed: 0', 'Prospect ID', 'Lead Number', 'Lead Origin',
#        'Lead Source', 'Do Not Email', 'Do Not Call', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity',
#        'Converted', 'Unnamed: 0.1'],
#       dtype='object')

# %% [markdown]
# ## data structure

# %%
import pandas as pd

def data_summary(df):
    print("#" * 60)
    print(f"Data Overview\n")
    print(f" Total Rows: {df.shape[0]:,}")
    print(f"Total Columns: {df.shape[1]:,}")
    print(f"Column Names:\n{list(df.columns)}")
    
    print("#" * 60)
    print("\n Data Types Overview")
    print(df.dtypes.value_counts())
    
    # Séparer les colonnes qualitatives et quantitatives
    qualitative_columns = df.select_dtypes(include=["object"]).columns.tolist()
    quantitative_columns = df.select_dtypes(include=["number"]).columns.tolist()
    
    print("\nQualitative Variables:")
    print(qualitative_columns if qualitative_columns else "None")
    
    print("\n Quantitative Variables:")
    print(quantitative_columns if quantitative_columns else "None")
    
    print("\n Missing Values Summary:")
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    if missing_values.empty:
        print("No missing values 🎉")
    else:
        print(missing_values)
    
    print("#" * 60)
data_summary(df)
# Out:
# ############################################################
# Data Overview
#
#  Total Rows: 9,240
# Total Columns: 39
# Column Names:
# ['Unnamed: 0', 'Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call', 'TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity', 'Country', 'Specialization', 'How did you hear about X Education', 'What is your current occupation', 'What matters most to you in choosing a course', 'Search', 'Magazine', 'Newspaper Article', 'X Education Forums', 'Newspaper', 'Digital Advertisement', 'Through Recommendations', 'Receive More Updates About Our Courses', 'Tags', 'Lead Quality', 'Update me on Supply Chain Content', 'Get updates on DM Content', 'Lead Profile', 'City', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index', 'Asymmetrique Activity Score', 'Asymmetrique Profile Score', 'I agree to pay the amount through cheque', 'A free copy of Mastering The Interview', 'Last Notable Activity', 'Converted', 'Unnamed: 0.1']
# ############################################################
#
#  Data Types Overview
# object     30
# float64     8
# int64       1
# Name: count, dtype: int64
#
# Qualitative Variables:
# ['Prospect ID', 'Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call', 'Last Activity', 'Country', 'Specialization', 'How did you hear about X Education', 'What is your current occupation', 'What matters most to you in choosing a course', 'Search', 'Magazine', 'Newspaper Article', 'X Education Forums', 'Newspaper', 'Digital Advertisement', 'Through Recommendations', 'Receive More Updates About Our Courses', 'Tags', 'Lead Quality', 'Update me on Supply Chain Content', 'Get updates on DM Content', 'Lead Profile', 'City', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index', 'I agree to pay the amount through cheque', 'A free copy of Mastering The Interview', 'Last Notable Activity']
#
#  Quantitative Variables:
# ['Unnamed: 0', 'Lead Number', 'TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit', 'Asymmetrique Activity Score', 'Asymmetrique Profile Score', 'Converted', 'Unnamed: 0.1']
#
#  Missing Values Summary:
# Lead Source                                        31
# TotalVisits                                        97
# Page Views Per Visit                               97
# Last Activity                                      72
# Country                                          1706
# Specialization                                    989
# How did you hear about X Education               1531
# What is your current occupation                  1847
# What matters most to you in choosing a course    1863
# Tags                                             2328
# Lead Quality                                     3295
# Lead Profile                                     1863
# City                                              974
# Asymmetrique Activity Index                      2947
# Asymmetrique Profile Index                       2947
# Asymmetrique Activity Score                      2947
# Asymmetrique Profile Score                       2947
# Converted                                        2772
# Unnamed: 0.1                                     6468
# dtype: int64
# ############################################################

# %%
def na(df, percent = True):
    srs = df.isna().sum()[df.isna().sum() > 0]
    srs = srs.sort_values(ascending=False)
    if percent:
        print('% of NaNs in df:')
        return srs / df.shape[0]
    else:
        print('# of NaNs in df:')
        return srs

na(df, False)
# Out:
# # of NaNs in df:
# Unnamed: 0.1                                     6468
# Lead Quality                                     3295
# Asymmetrique Profile Score                       2947
# Asymmetrique Activity Score                      2947
# Asymmetrique Profile Index                       2947
# Asymmetrique Activity Index                      2947
# Converted                                        2772
# Tags                                             2328
# What matters most to you in choosing a course    1863
# Lead Profile                                     1863
# What is your current occupation                  1847
# Country                                          1706
# How did you hear about X Education               1531
# Specialization                                    989
# City                                              974
# TotalVisits                                        97
# Page Views Per Visit                               97
# Last Activity                                      72
# Lead Source                                        31
# dtype: int64

# %%
#Calculate the percentage of NaNs per column
na_percentage = (df.isna().sum() / len(df)) * 100

# Filter out columns with no missing values
na_percentage = na_percentage[na_percentage > 0]

# Sort by the percentage of missing values
na_percentage = na_percentage.sort_values(ascending=False)
print(na_percentage)
# Plot the percentage of missing values
plt.figure(figsize=(15, 8))
na_percentage.plot(kind='bar', color='orange')
plt.title('Percentage of Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Percentage of Missing Values')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Unnamed: 0.1                                     70.000000
# Lead Quality                                     35.660173
# Asymmetrique Profile Score                       31.893939
# Asymmetrique Activity Score                      31.893939
# Asymmetrique Profile Index                       31.893939
# Asymmetrique Activity Index                      31.893939
# Converted                                        30.000000
# Tags                                             25.194805
# What matters most to you in choosing a course    20.162338
# Lead Profile                                     20.162338
# What is your current occupation                  19.989177
# Country                                          18.463203
# How did you hear about X Education               16.569264
# Specialization                                   10.703463
# City                                             10.541126
# TotalVisits                                       1.049784
# Page Views Per Visit                              1.049784
# Last Activity                                     0.779221
# Lead Source                                       0.335498
# dtype: float64

# %% [markdown]
# ## analyse univarie

# %% [markdown]
# ### numerical variables

# %%
dtypes = df.dtypes.to_frame().reset_index()
dtypes.columns = ['col', 'dtype']
print('Df dtypes:')
dtypes.groupby('dtype').size()
# Out:
# Df dtypes:
# dtype
# int64       1
# float64     8
# object     30
# dtype: int64

# %%
def numeric_analysis(df):
        return print(df.describe().T)
numeric_analysis(df)
# Out:
#                               count           mean           std       min  \
# Unnamed: 0                   9240.0    4619.500000   2667.502577       0.0
# Lead Number                  9240.0  617188.435606  23405.995698  579533.0
# TotalVisits                  9143.0       3.445192      4.844220       0.0
# Total Time Spent on Website  9240.0     487.698268    548.021466       0.0
# Page Views Per Visit         9143.0       2.362699      2.156685       0.0
# Asymmetrique Activity Score  6293.0      14.300240      1.238801       7.0
# Asymmetrique Profile Score   6293.0      16.325147      1.618607      11.0
# Converted                    6468.0       0.387755      0.487276       0.0
# Unnamed: 0.1                 2772.0    1385.500000    800.351798       0.0
#
#                                    25%            50%        75%       max
# Unnamed: 0                     2309.75    4619.500000    6929.25    9239.0
# Lead Number                  596484.50  615479.000000  637387.25  660737.0
# TotalVisits                       1.00       3.000000       5.00     251.0
# Total Time Spent on Website      12.00     248.000000     936.00    2272.0
# Page Views Per Visit              1.00       2.000000       3.00      55.0
# Asymmetrique Activity Score      14.00      14.276482      15.00      18.0
# Asymmetrique Profile Score       15.00      16.247169      18.00      20.0
# Converted                         0.00       0.000000       1.00       1.0
# Unnamed: 0.1                    692.75    1385.500000    2078.25    2771.0

# %%
df.set_index("Unnamed: 0", inplace=True)

# %% [markdown]
# #### Numerical varaiables visualization

# %%
def univariate_analysis(df, base_folder="univariate_analysis"):
        # Ensure the base folder exists
        if not os.path.exists(base_folder):
            os.makedirs(base_folder)
        
        # Select numeric columns
        numeric_cols = df.select_dtypes(include=['number']).columns
        
        for col in numeric_cols:
            # Create a folder for the analysis
            col_folder = os.path.join(base_folder, col)
            if not os.path.exists(col_folder):
                os.makedirs(col_folder)
            
            print(f"\nPerforming Univariate Analysis for: {col}")
            
            # Create a single figure with 2x2 layout
            fig, axes = plt.subplots(2, 2, figsize=(12, 10))
            fig.suptitle(f'Univariate Analysis for {col}', fontsize=16)
            
            # Bar Chart
            sns.barplot(
                x=df[col].value_counts().index, 
                y=df[col].value_counts().values, 
                palette="viridis", 
                ax=axes[0, 0]
            )
            axes[0, 0].set_title('Bar Chart')
            axes[0, 0].set_xlabel(col)
            axes[0, 0].set_ylabel('Frequency')
            
            # Box Plot
            sns.boxplot(y=df[col], palette="viridis", ax=axes[0, 1])
            axes[0, 1].set_title('Box Plot')
            axes[0, 1].set_xlabel(col)
            
            # Density Plot
            sns.kdeplot(df[col], fill=True, color="blue", alpha=0.6, ax=axes[1, 0])
            axes[1, 0].set_title('Density Plot')
            axes[1, 0].set_xlabel(col)
            axes[1, 0].set_ylabel('Density')
            
            # Histogram
            sns.histplot(df[col], kde=False, color="green", ax=axes[1, 1])
            axes[1, 1].set_title('Histogram')
            axes[1, 1].set_xlabel(col)
            axes[1, 1].set_ylabel('Frequency')
            
            # Adjust layout
            plt.tight_layout(rect=[0, 0, 1, 0.96])  # Make room for the main title
            
            # Save the combined plot
            combined_plot_path = os.path.join(col_folder, f"{col}_univariate_analysis.png")
            plt.savefig(combined_plot_path, bbox_inches='tight')
            plt.close()
            
            print(f"Combined plots for {col} saved in: {combined_plot_path}")

# %%
univariate_analysis(df, base_folder="univariate_analysis")
# Out:
# Performing Univariate Analysis for: Lead Number
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Combined plots for Lead Number saved in: univariate_analysis\Lead Number\Lead Number_univariate_analysis.png
#
# Performing Univariate Analysis for: TotalVisits
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Combined plots for TotalVisits saved in: univariate_analysis\TotalVisits\TotalVisits_univariate_analysis.png
#
# Performing Univariate Analysis for: Total Time Spent on Website
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Combined plots for Total Time Spent on Website saved in: univariate_analysis\Total Time Spent on Website\Total Time Spent on Website_univariate_analysis.png
#
# Performing Univariate Analysis for: Page Views Per Visit
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Combined plots for Page Views Per Visit saved in: univariate_analysis\Page Views Per Visit\Page Views Per Visit_univariate_analysis.png
#
# Performing Univariate Analysis for: Asymmetrique Activity Score
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Combined plots for Asymmetrique Activity Score saved in: univariate_analysis\Asymmetrique Activity Score\Asymmetrique Activity Score_univariate_analysis.png
#
# Performing Univariate Analysis for: Asymmetrique Profile Score
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Combined plots for Asymmetrique Profile Score saved in: univariate_analysis\Asymmetrique Profile Score\Asymmetrique Profile Score_univariate_analysis.png
#
# Performing Univariate Analysis for: Converted
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Combined plots for Converted saved in: univariate_analysis\Converted\Converted_univariate_analysis.png
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 univariate_analysis(df, base_folder="univariate_analysis")
#
# Cell In[25], line 13, in univariate_analysis(df, base_folder)
#      11 col_folder = os.path.join(base_folder, col)
#      12 if not os.path.exists(col_folder):
# ---> 13     os.makedirs(col_folder)
#      15 print(f"\nPerforming Univariate Analysis for: {col}")
#      17 # Create a single figure with 2x2 layout
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# NotADirectoryError: [WinError 267] Nom de répertoire non valide: 'univariate_analysis\\Unnamed: 0.1'

# %% [markdown]
# ### Categorical varaiables

# %%
def categorical_analysis(df):
    return print(df.select_dtypes(include='object').describe().T)
categorical_analysis(df)

# %% [markdown]
# ####  Categorical varaiables visualization

# %%
def univariate_analysis_categorical(df, base_folder="univariate_analysis_categorical"):
    # Ensure the base folder exists
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)
    
    # Select categorical columns
    categorical_cols = df.select_dtypes(include=['object', 'category']).columns
    
    for col in categorical_cols:
        # Create a folder for the analysis
        col_folder = os.path.join(base_folder, col)
        if not os.path.exists(col_folder):
            os.makedirs(col_folder)
        
        print(f"\nPerforming Univariate Analysis for: {col}")
        
        # Create a figure with 1x2 layout
        fig, axes = plt.subplots(1, 2, figsize=(15, 6))
        fig.suptitle(f'Univariate Analysis for {col}', fontsize=16)
        
        # Bar Plot
        sns.countplot(x=df[col], palette="viridis", ax=axes[0])
        axes[0].set_title('Count Plot')
        axes[0].set_xlabel(col)
        axes[0].set_ylabel('Frequency')
        axes[0].tick_params(axis='x', rotation=45)
        
        # Pie Chart
        df[col].value_counts().plot.pie(
            autopct='%1.1f%%', 
            colors=sns.color_palette("viridis", len(df[col].unique())),
            ax=axes[1], 
            startangle=90
        )
        axes[1].set_title('Pie Chart')
        axes[1].set_ylabel('')  # Remove y-label for better visualization
        
        # Adjust layout
        plt.tight_layout(rect=[0, 0, 1, 0.96])  # Make room for the main title
        
        # Save the combined plot
        combined_plot_path = os.path.join(col_folder, f"{col}_univariate_analysis.png")
        plt.savefig(combined_plot_path, bbox_inches='tight')
        plt.close()
        
        print(f"Combined plots for {col} saved in: {combined_plot_path}")
univariate_analysis_categorical(df, base_folder="univariate_analysis_categorical")
# Out:
# Performing Univariate Analysis for: Prospect ID
# Combined plots for Prospect ID saved in: univariate_analysis_categorical\Prospect ID\Prospect ID_univariate_analysis.png
#
# Performing Univariate Analysis for: Lead Origin
# Combined plots for Lead Origin saved in: univariate_analysis_categorical\Lead Origin\Lead Origin_univariate_analysis.png
#
# Performing Univariate Analysis for: Lead Source
# Combined plots for Lead Source saved in: univariate_analysis_categorical\Lead Source\Lead Source_univariate_analysis.png
#
# Performing Univariate Analysis for: Do Not Email
# Combined plots for Do Not Email saved in: univariate_analysis_categorical\Do Not Email\Do Not Email_univariate_analysis.png
#
# Performing Univariate Analysis for: Do Not Call
# Combined plots for Do Not Call saved in: univariate_analysis_categorical\Do Not Call\Do Not Call_univariate_analysis.png
#
# Performing Univariate Analysis for: Last Activity
# Combined plots for Last Activity saved in: univariate_analysis_categorical\Last Activity\Last Activity_univariate_analysis.png
#
# Performing Univariate Analysis for: Country
# Combined plots for Country saved in: univariate_analysis_categorical\Country\Country_univariate_analysis.png
#
# Performing Univariate Analysis for: Specialization
# Combined plots for Specialization saved in: univariate_analysis_categorical\Specialization\Specialization_univariate_analysis.png
#
# Performing Univariate Analysis for: How did you hear about X Education
# Combined plots for How did you hear about X Education saved in: univariate_analysis_categorical\How did you hear about X Education\How did you hear about X Education_univariate_analysis.png
#
# Performing Univariate Analysis for: What is your current occupation
# Combined plots for What is your current occupation saved in: univariate_analysis_categorical\What is your current occupation\What is your current occupation_univariate_analysis.png
#
# Performing Univariate Analysis for: What matters most to you in choosing a course
# Combined plots for What matters most to you in choosing a course saved in: univariate_analysis_categorical\What matters most to you in choosing a course\What matters most to you in choosing a course_univariate_analysis.png
#
# Performing Univariate Analysis for: Search
# Combined plots for Search saved in: univariate_analysis_categorical\Search\Search_univariate_analysis.png
#
# Performing Univariate Analysis for: Magazine
# Combined plots for Magazine saved in: univariate_analysis_categorical\Magazine\Magazine_univariate_analysis.png
#
# Performing Univariate Analysis for: Newspaper Article
# Combined plots for Newspaper Article saved in: univariate_analysis_categorical\Newspaper Article\Newspaper Article_univariate_analysis.png
#
# Performing Univariate Analysis for: X Education Forums
# Combined plots for X Education Forums saved in: univariate_analysis_categorical\X Education Forums\X Education Forums_univariate_analysis.png
#
# Performing Univariate Analysis for: Newspaper
# Combined plots for Newspaper saved in: univariate_analysis_categorical\Newspaper\Newspaper_univariate_analysis.png
#
# Performing Univariate Analysis for: Digital Advertisement
# Combined plots for Digital Advertisement saved in: univariate_analysis_categorical\Digital Advertisement\Digital Advertisement_univariate_analysis.png
#
# Performing Univariate Analysis for: Through Recommendations
# Combined plots for Through Recommendations saved in: univariate_analysis_categorical\Through Recommendations\Through Recommendations_univariate_analysis.png
#
# Performing Univariate Analysis for: Receive More Updates About Our Courses
# Combined plots for Receive More Updates About Our Courses saved in: univariate_analysis_categorical\Receive More Updates About Our Courses\Receive More Updates About Our Courses_univariate_analysis.png
#
# Performing Univariate Analysis for: Tags
# Combined plots for Tags saved in: univariate_analysis_categorical\Tags\Tags_univariate_analysis.png
#
# Performing Univariate Analysis for: Lead Quality
# Combined plots for Lead Quality saved in: univariate_analysis_categorical\Lead Quality\Lead Quality_univariate_analysis.png
#
# Performing Univariate Analysis for: Update me on Supply Chain Content
# Combined plots for Update me on Supply Chain Content saved in: univariate_analysis_categorical\Update me on Supply Chain Content\Update me on Supply Chain Content_univariate_analysis.png
#
# Performing Univariate Analysis for: Get updates on DM Content
# Combined plots for Get updates on DM Content saved in: univariate_analysis_categorical\Get updates on DM Content\Get updates on DM Content_univariate_analysis.png
#
# Performing Univariate Analysis for: Lead Profile
# Combined plots for Lead Profile saved in: univariate_analysis_categorical\Lead Profile\Lead Profile_univariate_analysis.png
#
# Performing Univariate Analysis for: City
# Combined plots for City saved in: univariate_analysis_categorical\City\City_univariate_analysis.png
#
# Performing Univariate Analysis for: Asymmetrique Activity Index
# Combined plots for Asymmetrique Activity Index saved in: univariate_analysis_categorical\Asymmetrique Activity Index\Asymmetrique Activity Index_univariate_analysis.png
#
# Performing Univariate Analysis for: Asymmetrique Profile Index
# Combined plots for Asymmetrique Profile Index saved in: univariate_analysis_categorical\Asymmetrique Profile Index\Asymmetrique Profile Index_univariate_analysis.png
#
# Performing Univariate Analysis for: I agree to pay the amount through cheque
# Combined plots for I agree to pay the amount through cheque saved in: univariate_analysis_categorical\I agree to pay the amount through cheque\I agree to pay the amount through cheque_univariate_analysis.png
#
# Performing Univariate Analysis for: A free copy of Mastering The Interview
# Combined plots for A free copy of Mastering The Interview saved in: univariate_analysis_categorical\A free copy of Mastering The Interview\A free copy of Mastering The Interview_univariate_analysis.png
#
# Performing Univariate Analysis for: Last Notable Activity
# Combined plots for Last Notable Activity saved in: univariate_analysis_categorical\Last Notable Activity\Last Notable Activity_univariate_analysis.png

# %% [markdown]
# ## Multyvarie Analysis

# %% [markdown]
# ### multivariate analysis with respect to the target variable

# %%
print(df["Converted"].value_counts(normalize=True) * 100)
# Out:
# Converted
# 0.0    61.22449
# 1.0    38.77551
# Name: proportion, dtype: float64

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor
target = "Converted"
def multivariate_analysis(target, df, base_folder="multivariate_analysis", sample_frac=0.2):
    """
    Performs multivariate analysis with respect to the target variable.
    Outputs:
        - Categorical vs Target: Histograms with Density Curves separately by modality.
        - Numeric vs Target: Scatter plots with Density Curves separately by modality.
    
    Parameters:
        df (pd.DataFrame): The DataFrame to analyze.
        target (str): The target variable for comparison.
        base_folder (str): Directory to save the analysis images.
        sample_frac (float): Fraction of data to sample for faster plotting.
    """
    # Ensure the base folder exists
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)
    
    # --- Categorical vs Target ---
    cat_vs_target_folder = os.path.join(base_folder, "categorical_vs_target")
    if not os.path.exists(cat_vs_target_folder):
        os.makedirs(cat_vs_target_folder)
    
    # Select categorical columns
    categorical_cols = df.select_dtypes(include=['object', 'category']).columns
    
    def plot_categorical_vs_target(col):
        print(f"\nAnalyzing Categorical vs Target: {target} vs {col}")
        
        # Create a grid of histograms by modality of the categorical variable
        modalities = df[col].unique()
        n_modalities = len(modalities)
        fig, axes = plt.subplots(1, n_modalities, figsize=(6 * n_modalities, 6), sharey=True)
        
        if n_modalities == 1:
            axes = [axes]  # To handle single modality case
        
        for i, modality in enumerate(modalities):
            subset = df[df[col] == modality]
            sns.histplot(
                subset[target], kde=True, ax=axes[i], alpha=0.6, color='skyblue'
            )
            axes[i].set_title(f'{col} = {modality}')
            axes[i].set_xlabel(target)
            axes[i].set_ylabel('Frequency')
        
        plt.suptitle(f'{target} Distribution by {col} (Separate by Modality)', fontsize=16)
        plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout for main title
        
        # Save plot
        plot_path = os.path.join(cat_vs_target_folder, f"{target}_vs_{col}.png")
        plt.savefig(plot_path, bbox_inches='tight')
        plt.close()
        print(f"Categorical vs Target (Histograms) saved in: {plot_path}")
    
    # Parallelize the plotting for categorical vs target
    with ThreadPoolExecutor() as executor:
        executor.map(plot_categorical_vs_target, categorical_cols)
    
    # --- Numeric vs Target ---
    num_vs_target_folder = os.path.join(base_folder, "numeric_vs_target")
    if not os.path.exists(num_vs_target_folder):
        os.makedirs(num_vs_target_folder)
    
    # Select numeric columns
    numeric_cols = df.select_dtypes(include=['float64','int64']).columns
    
    def plot_numeric_vs_target(col):
        print(f"\nAnalyzing Numeric vs Target: {target} vs {col}")
        
        # Sample the data for faster plotting
        sampled_df = df.sample(frac=sample_frac, random_state=42)
        
        # Create a grid of scatter plots by modality of the target variable
        modalities = sampled_df[target].unique()
        n_modalities = len(modalities)
        fig, axes = plt.subplots(1, n_modalities, figsize=(6 * n_modalities, 6), sharey=True)
        
        if n_modalities == 1:
            axes = [axes]  # To handle single modality case
        
        for i, modality in enumerate(modalities):
            subset = sampled_df[sampled_df[target] == modality]
            sns.scatterplot(
                x=target, y=col, data=subset, ax=axes[i], alpha=0.4, color='purple'
            )
            sns.kdeplot(
                data=subset, x=target, y=col, ax=axes[i], color="red", levels=3, linewidths=1
            )
            axes[i].set_title(f'{target} = {modality}')
            axes[i].set_xlabel(target)
            axes[i].set_ylabel(col)
        
        plt.suptitle(f'{target} vs {col} (Scatter + Density by Modality)', fontsize=16)
        plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout for main title
        
        # Save plot
        plot_path = os.path.join(num_vs_target_folder, f"{target}_vs_{col}.png")
        plt.savefig(plot_path, bbox_inches='tight')
        plt.close()
        
        print(f"Numeric vs Target (Scatter + Density) saved in: {plot_path}")
    
    # Parallelize the plotting for numeric vs target
    with ThreadPoolExecutor() as executor:
        executor.map(plot_numeric_vs_target, numeric_cols)
multivariate_analysis(target,df,base_folder="multivariate_analysis")
# Out:
# Analyzing Categorical vs Target: Converted vs Prospect ID
#
# Analyzing Categorical vs Target: Converted vs Lead Origin
#
# Analyzing Categorical vs Target: Converted vs Lead Source
#
# Analyzing Categorical vs Target: Converted vs Do Not Email
#
# Analyzing Categorical vs Target: Converted vs Do Not Call
#
# Analyzing Categorical vs Target: Converted vs Last Activity
#
# Analyzing Categorical vs Target: Converted vs Country
#
# Analyzing Categorical vs Target: Converted vs Specialization
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Client\anaconda3\Nouveau dossier\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Client\AppData\Local\Temp\ipykernel_10412\4288458212.py:54: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout for main title
# C:\Users\Client\AppData\Local\Temp\ipykernel_10412\4288458212.py:54: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout for main title
# C:\Users\Client\AppData\Local\Temp\ipykernel_10412\4288458212.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout for main title
# Categorical vs Target (Histograms) saved in: multivariate_analysis\categorical_vs_target\Converted_vs_Do Not Call.png
#
# Analyzing Categorical vs Target: Converted vs How did you hear about X Education
# Categorical vs Target (Histograms) saved in: multivariate_analysis\categorical_vs_target\Converted_vs_Do Not Email.png
#
# Analyzing Categorical vs Target: Converted vs What is your current occupation

# %% [markdown]
# ### Multyvarie Analysis advanced

# %%
def scatter_plot_combinations(target, df, base_folder="scatter_combinations"):
    """
    Generates scatter plots for all possible combinations between the target variable,
    one categorical variable, and one numerical variable.
    Outputs:
        - Scatter plots showing the relationship between target and numerical variable,
          colored by the categories of the categorical variable.
    
    Parameters:
        df (pd.DataFrame): The DataFrame to analyze.
        target (str): The target variable for comparison.
        base_folder (str): Directory to save the scatter plots.
    """
    # Ensure the base folder exists
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)
    
    # Select categorical and numeric columns
    categorical_cols = df.select_dtypes(include=['object', 'category']).columns
    numeric_cols = df.select_dtypes(include=['number']).columns
    
    # Iterate through all combinations of categorical and numerical variables
    for cat_col in categorical_cols:
        if cat_col != target:  # Skip the target itself
            for num_col in numeric_cols:
                if num_col != target:  # Skip the target itself
                    print(f"\nCreating Scatter Plot: Target={target}, Categorical={cat_col}, Numerical={num_col}")
                    
                    # Plot
                    plt.figure(figsize=(10, 6))
                    sns.scatterplot(
                        x=num_col, 
                        y=target, 
                        hue=cat_col, 
                        data=df, 
                        palette="viridis", 
                        alpha=0.6
                    )
                    plt.title(f'{target} vs {num_col} by {cat_col}')
                    plt.xlabel(num_col)
                    plt.ylabel(target)
                    plt.legend(title=cat_col)
                    
                    # Save plot
                    plot_folder = os.path.join(base_folder, f"{target}_vs_{num_col}_by_{cat_col}")
                    if not os.path.exists(plot_folder):
                        os.makedirs(plot_folder)
                    plot_path = os.path.join(plot_folder, f"{target}_vs_{num_col}_by_{cat_col}.png")
                    plt.savefig(plot_path, bbox_inches='tight')
                    plt.close()
                    
                    print(f"Scatter Plot saved in: {plot_path}")
scatter_plot_combinations(target, df, base_folder="scatter_combinations")

# %% [markdown]
# ### Correlation matrix

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Supprimer les lignes contenant des NaN ou des inf
column_headers = df.columns.to_list()
quantitative_columns = [col for col in column_headers if df[col].dtype in ['int64', 'float64']]

# Nettoyage des valeurs infinies et manquantes
cleaned_df = df[quantitative_columns].replace([np.inf, -np.inf], np.nan).dropna()

# Vérifier si les valeurs infinies ou NaN ont disparu
print(cleaned_df.isna().sum())  # Devrait afficher 0 partout

def correlation_and_significance(numeric_df, base_folder="correlation_analysis"):
    """
    Generates a correlation matrix heatmap with significance markers.
    
    Parameters:
        numeric_df (pd.DataFrame): The cleaned DataFrame with numerical variables.
        base_folder (str): Directory to save the analysis images.
    """
    # Assurer l'existence du dossier de sauvegarde
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)
    
    cols = numeric_df.columns
    
    # Calculer la matrice de corrélation
    corr_matrix = numeric_df.corr()
    
    # Initialiser la matrice des p-values
    p_values = pd.DataFrame(np.ones((len(cols), len(cols))), columns=cols, index=cols)
    
    # Calculer les p-values pour chaque paire de variables
    for row in cols:
        for col in cols:
            if row != col:
                _, p_value = pearsonr(numeric_df[row], numeric_df[col])
                p_values.loc[row, col] = p_value
    
    # --- Affichage de la matrice de corrélation avec significativité ---
    plt.figure(figsize=(14, 12))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

    # Ajouter des marqueurs de significativité
    for i in range(len(cols)):
        for j in range(len(cols)):
            if i != j:  # Ne pas marquer la diagonale
                p_val = p_values.iloc[i, j]
                x = j + 0.5
                y = i + 0.5
                
                # Vert si significatif (p < 0.05), rouge sinon
                color = 'green' if p_val < 0.05 else 'red'
                plt.plot(x, y, 'o', color=color)
    
    plt.title('Correlation Matrix with Significance (Numerical Variables)', fontsize=18)
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    
    # Sauvegarde de l'image
    corr_plot_path = os.path.join(base_folder, "correlation_matrix_significance.png")
    plt.savefig(corr_plot_path, bbox_inches='tight')
    plt.close()
    
    print(f"Correlation matrix with significance saved in: {corr_plot_path}")

# Exécuter la fonction avec les données nettoyées
correlation_and_significance(cleaned_df, base_folder="correlation_analysis")

# %% [markdown]
# ## General Analysis
